# %%
import pandas as pd
import pymongo

# %%
url='https://raw.githubusercontent.com/omarmendoza564/datos/main/datos/titanic.csv'
df_titanic= pd.read_csv(url)
type(df_titanic)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # Catalogo:
# #### pclase – Tipo de Boleto, e.g 1 = 1ra, 2 = 2da, 3 = 3ra
# #### survival – Sí la persona sobrevivió o no el accidente (1|0)
# #### name – Nombre del pasajero y titulo incluido
# #### sex – Género del pasajero: female|male
# #### age – Edad en años
# #### sibsp – Número de parientes/cónyuges abordo del Titanic
# #### parch – Número de padres/hijos abordo del Titanic
# #### ticket – Número de Boleto
# #### fare – Costo del boleto
# #### cabin – Número cabina
# #### embarked – Puerto de embarcación (C = Cherburgo; Q = Queenstown; S = Southampton)
# #### boat - Número de bote salvavidas, si tomó alguno
# #### body - Número de cuerpo (si no sobrevivió y se recuperó el cuerpo)
# #### home.dest - Origen y destino del pasajero

# %%
print(df_titanic)
# Out:
#       pclass  survived                                             name  \
# 0        1.0       1.0                    Allen, Miss. Elisabeth Walton
# 1        1.0       1.0                   Allison, Master. Hudson Trevor
# 2        1.0       0.0                     Allison, Miss. Helen Loraine
# 3        1.0       0.0             Allison, Mr. Hudson Joshua Creighton
# 4        1.0       0.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1305     3.0       0.0                            Zabour, Miss. Thamine
# 1306     3.0       0.0                        Zakarian, Mr. Mapriededer
# 1307     3.0       0.0                              Zakarian, Mr. Ortin
# 1308     3.0       0.0                               Zimmerman, Mr. Leo
# 1309     NaN       NaN                                              NaN
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
df_titanic
# Out:
#       pclass  survived                                             name  \
# 0        1.0       1.0                    Allen, Miss. Elisabeth Walton
# 1        1.0       1.0                   Allison, Master. Hudson Trevor
# 2        1.0       0.0                     Allison, Miss. Helen Loraine
# 3        1.0       0.0             Allison, Mr. Hudson Joshua Creighton
# 4        1.0       0.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1305     3.0       0.0                            Zabour, Miss. Thamine
# 1306     3.0       0.0                        Zakarian, Mr. Mapriededer
# 1307     3.0       0.0                              Zakarian, Mr. Ortin
# 1308     3.0       0.0                               Zimmerman, Mr. Leo
# 1309     NaN       NaN                                              NaN
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
#1. Si la edad es null (na) llenar el campo con la media de la edad (usar el metodo fillna())
df_titanic['age'].fillna(df_titanic['age'].mean(), inplace=True)
df_titanic
#El promedio es 29.881135, fue aplicado minimo en el indice 1305
# Out:
#       pclass  survived                                             name  \
# 0        1.0       1.0                    Allen, Miss. Elisabeth Walton
# 1        1.0       1.0                   Allison, Master. Hudson Trevor
# 2        1.0       0.0                     Allison, Miss. Helen Loraine
# 3        1.0       0.0             Allison, Mr. Hudson Joshua Creighton
# 4        1.0       0.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1305     3.0       0.0                            Zabour, Miss. Thamine
# 1306     3.0       0.0                        Zakarian, Mr. Mapriededer
# 1307     3.0       0.0                              Zakarian, Mr. Ortin
# 1308     3.0       0.0                               Zimmerman, Mr. Leo
# 1309     NaN       NaN                                              NaN
#
#          sex        age  sibsp  parch  ticket      fare    cabin embarked  \
# ...

# %%
#2. Si embarqued es na llenar con S
df_titanic['embarked'].fillna('S',inplace=True)
df_titanic
# Out:
#       pclass  survived                                             name  \
# 0        1.0       1.0                    Allen, Miss. Elisabeth Walton
# 1        1.0       1.0                   Allison, Master. Hudson Trevor
# 2        1.0       0.0                     Allison, Miss. Helen Loraine
# 3        1.0       0.0             Allison, Mr. Hudson Joshua Creighton
# 4        1.0       0.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1305     3.0       0.0                            Zabour, Miss. Thamine
# 1306     3.0       0.0                        Zakarian, Mr. Mapriededer
# 1307     3.0       0.0                              Zakarian, Mr. Ortin
# 1308     3.0       0.0                               Zimmerman, Mr. Leo
# 1309     NaN       NaN                                              NaN
#
#          sex        age  sibsp  parch  ticket      fare    cabin embarked  \
# ...

# %%
#3. Cambiar los valores alfanumericos de sex a numero usando { 'female': 1, 'male': 0 }
#UTILIZANDO REPLACE(TO_REPLACE)

df_titanic['sex']=df_titanic['sex'].replace(to_replace="female",value=1,regex = True)
df_titanic['sex'] = df_titanic['sex'].replace(to_replace="male",value=0,regex = True)
df_titanic

#Cuando encuentre un sex vacio, asi lo dejara ya que no se nos especifico que se cambiara
# Out:
#       pclass  survived                                             name  sex  \
# 0        1.0       1.0                    Allen, Miss. Elisabeth Walton  1.0
# 1        1.0       1.0                   Allison, Master. Hudson Trevor  0.0
# 2        1.0       0.0                     Allison, Miss. Helen Loraine  1.0
# 3        1.0       0.0             Allison, Mr. Hudson Joshua Creighton  0.0
# 4        1.0       0.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  1.0
# ...      ...       ...                                              ...  ...
# 1305     3.0       0.0                            Zabour, Miss. Thamine  1.0
# 1306     3.0       0.0                        Zakarian, Mr. Mapriededer  0.0
# 1307     3.0       0.0                              Zakarian, Mr. Ortin  0.0
# 1308     3.0       0.0                               Zimmerman, Mr. Leo  0.0
# 1309     NaN       NaN                                              NaN  NaN
#
# ...

# %%
#4. Cambiar los valores alfanumericos de embarked a numero usando { 'S': 0, 'C': 1, 'Q': 2 }
#embarked – Puerto de embarcación (C = Cherburgo = 1; Q = Queenstown = 2; S = Southampton =0)
#Uso de diccionarios 
df_titanic['embarked']= df_titanic['embarked'].replace({'S':0,'C':1,'Q':2})
df_titanic
# Out:
#       pclass  survived                                             name  sex  \
# 0        1.0       1.0                    Allen, Miss. Elisabeth Walton  1.0
# 1        1.0       1.0                   Allison, Master. Hudson Trevor  0.0
# 2        1.0       0.0                     Allison, Miss. Helen Loraine  1.0
# 3        1.0       0.0             Allison, Mr. Hudson Joshua Creighton  0.0
# 4        1.0       0.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  1.0
# ...      ...       ...                                              ...  ...
# 1305     3.0       0.0                            Zabour, Miss. Thamine  1.0
# 1306     3.0       0.0                        Zakarian, Mr. Mapriededer  0.0
# 1307     3.0       0.0                              Zakarian, Mr. Ortin  0.0
# 1308     3.0       0.0                               Zimmerman, Mr. Leo  0.0
# 1309     NaN       NaN                                              NaN  NaN
#
# ...

# %%
#5. Crear una nueva variable llamada child con valor 1 para los pasajeros con una edad menor a 16 años y 0 si el pasajero tiene 16 años o mas
df_titanic['child'] = (df_titanic['age'] < 16).astype(int)
df_titanic

#la comparación junto con el comando "astype", nos devolvera una expresión booleana, escribiendo un 1 si lo cumple o un 0 si no
# Out:
#       pclass  survived                                             name  sex  \
# 0        1.0       1.0                    Allen, Miss. Elisabeth Walton  1.0
# 1        1.0       1.0                   Allison, Master. Hudson Trevor  0.0
# 2        1.0       0.0                     Allison, Miss. Helen Loraine  1.0
# 3        1.0       0.0             Allison, Mr. Hudson Joshua Creighton  0.0
# 4        1.0       0.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  1.0
# ...      ...       ...                                              ...  ...
# 1305     3.0       0.0                            Zabour, Miss. Thamine  1.0
# 1306     3.0       0.0                        Zakarian, Mr. Mapriededer  0.0
# 1307     3.0       0.0                              Zakarian, Mr. Ortin  0.0
# 1308     3.0       0.0                               Zimmerman, Mr. Leo  0.0
# 1309     NaN       NaN                                              NaN  NaN
#
# ...

# %%
#6. Eliminar las columnas ticket, cabin y name
#Dropna SOLO ES PARA NULOS!!!!
df_titanic.drop('ticket', axis=1, inplace=True)
df_titanic.drop('cabin',axis=1,inplace=True)
df_titanic.drop('name',axis=1,inplace=True)
df_titanic
# Out:
#       pclass  survived  sex        age  sibsp  parch      fare  embarked boat  \
# 0        1.0       1.0  1.0  29.000000    0.0    0.0  211.3375         0    2
# 1        1.0       1.0  0.0   0.916700    1.0    2.0  151.5500         0   11
# 2        1.0       0.0  1.0   2.000000    1.0    2.0  151.5500         0  NaN
# 3        1.0       0.0  0.0  30.000000    1.0    2.0  151.5500         0  NaN
# 4        1.0       0.0  1.0  25.000000    1.0    2.0  151.5500         0  NaN
# ...      ...       ...  ...        ...    ...    ...       ...       ...  ...
# 1305     3.0       0.0  1.0  29.881135    1.0    0.0   14.4542         1  NaN
# 1306     3.0       0.0  0.0  26.500000    0.0    0.0    7.2250         1  NaN
# 1307     3.0       0.0  0.0  27.000000    0.0    0.0    7.2250         1  NaN
# 1308     3.0       0.0  0.0  29.000000    0.0    0.0    7.8750         0  NaN
# 1309     NaN       NaN  NaN  29.881135    NaN    NaN       NaN         0  NaN
#
# ...

# %%
#7. Validar que no existan registros duplicados
if df_titanic.duplicated().any():
    print("Hay registros duplicados")
else:
    print("Ningun tripulante repite datos")
df_titanic
# Out:
# Hay registros duplicados
#       pclass  survived  sex        age  sibsp  parch      fare  embarked boat  \
# 0        1.0       1.0  1.0  29.000000    0.0    0.0  211.3375         0    2
# 1        1.0       1.0  0.0   0.916700    1.0    2.0  151.5500         0   11
# 2        1.0       0.0  1.0   2.000000    1.0    2.0  151.5500         0  NaN
# 3        1.0       0.0  0.0  30.000000    1.0    2.0  151.5500         0  NaN
# 4        1.0       0.0  1.0  25.000000    1.0    2.0  151.5500         0  NaN
# ...      ...       ...  ...        ...    ...    ...       ...       ...  ...
# 1305     3.0       0.0  1.0  29.881135    1.0    0.0   14.4542         1  NaN
# 1306     3.0       0.0  0.0  26.500000    0.0    0.0    7.2250         1  NaN
# 1307     3.0       0.0  0.0  27.000000    0.0    0.0    7.2250         1  NaN
# 1308     3.0       0.0  0.0  29.000000    0.0    0.0    7.8750         0  NaN
# 1309     NaN       NaN  NaN  29.881135    NaN    NaN       NaN         0  NaN
#
# ...

# %%
#8. Listar los valores unicos del campo sex
print(df_titanic['sex'].unique())
# Out:
# [ 1.  0. nan]

# %%
df_titanic
# Out:
#       pclass  survived  sex        age  sibsp  parch      fare  embarked boat  \
# 0        1.0       1.0  1.0  29.000000    0.0    0.0  211.3375         0    2
# 1        1.0       1.0  0.0   0.916700    1.0    2.0  151.5500         0   11
# 2        1.0       0.0  1.0   2.000000    1.0    2.0  151.5500         0  NaN
# 3        1.0       0.0  0.0  30.000000    1.0    2.0  151.5500         0  NaN
# 4        1.0       0.0  1.0  25.000000    1.0    2.0  151.5500         0  NaN
# ...      ...       ...  ...        ...    ...    ...       ...       ...  ...
# 1305     3.0       0.0  1.0  29.881135    1.0    0.0   14.4542         1  NaN
# 1306     3.0       0.0  0.0  26.500000    0.0    0.0    7.2250         1  NaN
# 1307     3.0       0.0  0.0  27.000000    0.0    0.0    7.2250         1  NaN
# 1308     3.0       0.0  0.0  29.000000    0.0    0.0    7.8750         0  NaN
# 1309     NaN       NaN  NaN  29.881135    NaN    NaN       NaN         0  NaN
#
# ...

# %%
#9. Quitar los espacios vacios de los campos que no sean numericos
#Quitar caracteres en blanco
df_titanic['home.dest'] = df_titanic['home.dest'].str.strip()
df_titanic
# Out:
#       pclass  survived  sex        age  sibsp  parch      fare  embarked boat  \
# 0        1.0       1.0  1.0  29.000000    0.0    0.0  211.3375         0    2
# 1        1.0       1.0  0.0   0.916700    1.0    2.0  151.5500         0   11
# 2        1.0       0.0  1.0   2.000000    1.0    2.0  151.5500         0  NaN
# 3        1.0       0.0  0.0  30.000000    1.0    2.0  151.5500         0  NaN
# 4        1.0       0.0  1.0  25.000000    1.0    2.0  151.5500         0  NaN
# ...      ...       ...  ...        ...    ...    ...       ...       ...  ...
# 1305     3.0       0.0  1.0  29.881135    1.0    0.0   14.4542         1  NaN
# 1306     3.0       0.0  0.0  26.500000    0.0    0.0    7.2250         1  NaN
# 1307     3.0       0.0  0.0  27.000000    0.0    0.0    7.2250         1  NaN
# 1308     3.0       0.0  0.0  29.000000    0.0    0.0    7.8750         0  NaN
# 1309     NaN       NaN  NaN  29.881135    NaN    NaN       NaN         0  NaN
#
# ...
